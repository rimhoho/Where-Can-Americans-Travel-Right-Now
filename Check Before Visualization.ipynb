# %%
import pandas as pd
import plotly.graph_objects as go

# %%
df = pd.read_json('https://covid.ourworldindata.org/data/owid-covid-data.json').T.reset_index()
df
# Out:
#         index continent        location   population population_density  \
# 0         AFG      Asia     Afghanistan  3.89283e+07             54.422
# 1         ALB    Europe         Albania   2.8778e+06            104.871
# 2         DZA    Africa         Algeria   4.3851e+07             17.348
# 3         AND    Europe         Andorra        77265            163.755
# 4         AGO    Africa          Angola  3.28663e+07              23.89
# ..        ...       ...             ...          ...                ...
# 206       ESH    Africa  Western Sahara       597330                NaN
# 207       YEM      Asia           Yemen   2.9826e+07             53.508
# 208       ZMB    Africa          Zambia   1.8384e+07             22.995
# 209       ZWE    Africa        Zimbabwe  1.48629e+07             42.729
# 210  OWID_WRL       NaN           World   7.7948e+09             58.045
#
#     median_age aged_65_older aged_70_older gdp_per_capita cvd_death_rate  \
# ...

# %%
# Out:
# [{'date': '2019-12-31', 'total_cases': 0.0, 'new_cases': 0.0, 'total_deaths': 0.0, 'new_deaths': 0.0, 'total_cases_per_million': 0.0, 'new_cases_per_million': 0.0, 'total_deaths_per_million': 0.0, 'new_deaths_per_million': 0.0}, {'date': '2020-01-01', 'total_cases': 0.0, 'new_cases': 0.0, 'total_deaths': 0.0, 'new_deaths': 0.0, 'total_cases_per_million': 0.0, 'new_cases_per_million': 0.0, 'total_deaths_per_million': 0.0, 'new_deaths_per_million': 0.0, 'stringency_index': 0.0}, {'date': '2020-01-02', 'total_cases': 0.0, 'new_cases': 0.0, 'total_deaths': 0.0, 'new_deaths': 0.0, 'total_cases_per_million': 0.0, 'new_cases_per_million': 0.0, 'total_deaths_per_million': 0.0, 'new_deaths_per_million': 0.0, 'stringency_index': 0.0}, {'date': '2020-01-03', 'total_cases': 0.0, 'new_cases': 0.0, 'total_deaths': 0.0, 'new_deaths': 0.0, 'total_cases_per_million': 0.0, 'new_cases_per_million': 0.0, 'total_deaths_per_million': 0.0, 'new_deaths_per_million': 0.0, 'stringency_index': 0.0}, {'date': '
# ...

# %%
# Specific country: United States
us = df.loc[lambda df:df['location'] == 'United States']['data'].tolist()
us[0][0]
# Out:
# {'date': '2019-12-31',
#  'total_cases': 0.0,
#  'new_cases': 0.0,
#  'total_deaths': 0.0,
#  'new_deaths': 0.0,
#  'total_cases_per_million': 0.0,
#  'new_cases_per_million': 0.0,
#  'total_deaths_per_million': 0.0,
#  'new_deaths_per_million': 0.0}

# %%
for arr in us:
    USA = pd.DataFrame({'date': us['date'],
                         'total_cases': us['aged_65_older'],
                         'new_cases': us['new_cases'],
                         'gdp_per_capita': us['gdp_per_capita'],
                         'cvd_death_rate': us['cvd_death_rate'],
                         'diabetes_prevalence': us['diabetes_prevalence']
                        }).reset_index().drop(columns=['index'])
USA.head(3)
# Out:
#         location aged_over_65 hospital_beds_per_thousand gdp_per_capita  \
# 0  United States       25.145                       2.77        54225.4
#
#   cvd_death_rate diabetes_prevalence
# 0        151.089               10.79

# %%
df_world = pd.DataFrame({'date': [pd.to_datetime(d.get('date'),format='%Y-%m-%d') for d in df.loc[210]['data']],
                      'new_cases':[d.get('new_cases') for d in df.loc[210]['data']],
                      'new_deaths':[d.get('new_deaths') for d in df.loc[210]['data']],
                      'total_cases':[d.get('total_cases') for d in df.loc[210]['data']],
                      'total_deaths':[d.get('total_deaths') for d in df.loc[210]['data']],
#                       'new_cases_per_million':[d.get('new_cases_per_million') for d in df.loc[210]['data']],
#                       'new_deaths_per_million':[d.get('new_deaths_per_million') for d in df.loc[210]['data']],
#                       'total_cases_per_million':[d.get('total_cases_per_million') for d in df.loc[210]['data']],
#                       'total_deaths_per_million':[d.get('total_deaths_per_million') for d in df.loc[210]['data']]
                     })
df_world.head(3)
# Out:
#         date  new_cases  new_deaths  total_cases  total_deaths
# 0 2019-12-31       27.0         0.0         27.0           0.0
# 1 2020-01-01        0.0         0.0         27.0           0.0
# 2 2020-01-02        0.0         0.0         27.0           0.0

# %%
# df_world.sort_values(by=['new_cases_per_million'], inplace=True)

# %%
# df_world_new = add_daily_measures(df_world)
df_world['Cases:14-day'] = df_world['new_cases'].rolling(14).mean()
df_world['Deaths:14-day'] = df_world['new_deaths'].rolling(14).mean()
df_world.head(16)
# Out:
#          date  new_cases  new_deaths  total_cases  total_deaths  Cases:14-day  \
# 0  2019-12-31       27.0         0.0         27.0           0.0           NaN
# 1  2020-01-01        0.0         0.0         27.0           0.0           NaN
# 2  2020-01-02        0.0         0.0         27.0           0.0           NaN
# 3  2020-01-03       17.0         0.0         44.0           0.0           NaN
# 4  2020-01-04        0.0         0.0         44.0           0.0           NaN
# 5  2020-01-05       15.0         0.0         59.0           0.0           NaN
# 6  2020-01-06        0.0         0.0         59.0           0.0           NaN
# 7  2020-01-07        0.0         0.0         59.0           0.0           NaN
# 8  2020-01-08        0.0         0.0         59.0           0.0           NaN
# 9  2020-01-09        0.0         0.0         59.0           0.0           NaN
# 10 2020-01-10        0.0         0.0         59.0           0.0           NaN
# ...

# %%
df_world_new = df_world.groupby('date',as_index=False)['new_cases','new_deaths'].sum()
fig = go.Figure(data=[
    go.Bar(name='New Cases', x=df_world['date'], y=df_world['new_cases']),
    go.Bar(name='New Deaths', x=df_world['date'], y=df_world['new_deaths'])
])
fig.add_trace(go.Scatter(name='Cases:14-day',x=df_world['date'],y=df_world['Cases:14-day'],marker_color='black'))
fig.add_trace(go.Scatter(name='Deaths:14-day',x=df_world['date'],y=df_world['Deaths:14-day'],marker_color='darkred'))

# Change the bar mode
fig.update_layout(barmode='overlay', title='Worldwide daily Case and Death count',showlegend=False)
fig.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <div>
#
#
#             <div id="ba4c5476-e01b-4d4d-8ead-b638e905f0fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ba4c5476-e01b-4d4d-8ead-b638e905f0fd")) {
#                     Plotly.newPlot(
#                         'ba4c5476-e01b-4d4d-8ead-b638e905f0fd',
# ...

# %%
data = pd.DataFrame({'location': df['location'],
                     'aged_over_65': df['aged_65_older'] + df['aged_70_older'],
                     'hospital_beds_per_thousand': df['hospital_beds_per_thousand'],
                     'gdp_per_capita': df['gdp_per_capita'],
                     'cvd_death_rate': df['cvd_death_rate'],
                     'diabetes_prevalence': df['diabetes_prevalence'],
                     'latest_date': [df['data'][col][-1]['date'] if 'date' in df['data'][col][-1] else df['data'][col][-1] for col in range(len(df['data']))],
                     'total_cases' : [df['data'][col][-1]['total_cases'] if 'total_cases' in df['data'][col][-1] else None for col in range(len(df['data']))],
                     'total_deaths' : [df['data'][col][-1]['total_deaths'] if 'total_deaths' in df['data'][col][-1] else None for col in range(len(df['data']))],
                     'total_cases_per_million' : [df['data'][col][-1]['total_cases_per_million'] if 'total_cases_per_million' in df['data'][col][-1] else None for col in range(len(df['data']))],
                     'total_deaths_per_million' : [df['data'][col][-1]['total_deaths_per_million'] if 'total_deaths_per_million' in df['data'][col][-1] else None for col in range(len(df['data']))]
                    }).reset_index().drop(columns=['index'])
data.head(3)
# Out:
#       location aged_over_65 hospital_beds_per_thousand gdp_per_capita  \
# 0  Afghanistan        3.918                        0.5        1803.99
# 1      Albania       21.831                       2.89        11803.4
# 2      Algeria       10.068                        1.9        13913.8
#
#   cvd_death_rate diabetes_prevalence latest_date  total_cases  total_deaths  \
# 0        597.029                9.59  2020-07-11      34366.0         994.0
# 1        304.195               10.08  2020-07-11       3278.0          85.0
# 2        278.364                6.73  2020-07-11      17808.0         988.0
#
#    total_cases_per_million  total_deaths_per_million
# 0                  882.802                    25.534
# 1                 1139.065                    29.536
# 2                  406.102                    22.531

# %%
data.sort_values(by=['total_cases'], inplace=True, ascending=False)

# %%
data.head(20)
# Out:
#            location aged_over_65 hospital_beds_per_thousand gdp_per_capita  \
# 210           World       14.051                      2.705        15469.2
# 199   United States       25.145                       2.77        54225.4
# 27           Brazil       13.612                        2.2        14103.5
# 90            India        9.403                       0.53        6426.67
# 157          Russia       23.571                       8.05          24766
# 150            Peru       11.606                        1.6        12236.7
# 40            Chile       18.025                       2.11          22767
# 125          Mexico       11.178                       1.38        17336.5
# 198  United Kingdom       31.044                       2.54        39753.2
# 177           Spain       33.235                       2.97        34272.4
# 92             Iran        8.622                        1.5        19082.6
# ...

# %%
data.tail(20)
# Out:
#                              location aged_over_65 hospital_beds_per_thousand  \
# 142          Northern Mariana Islands          NaN                        NaN
# 161  Saint Vincent and the Grenadines       12.556                        2.6
# 49                            Curacao       26.435                        NaN
# 189                             Timor        5.453                        5.9
# 78                            Grenada       12.325                        3.7
# 160                       Saint Lucia       16.126                        1.3
# 137                     New Caledonia       16.443                        NaN
# 66                               Fiji        9.508                        2.3
# 107                              Laos        6.351                        1.5
# 55                           Dominica          NaN                        3.8
# 159             Saint Kitts and Nevis          NaN                        2.3
# ...

# %%
import pandas as pd
import numpy as np
s = pd.DataFrame({'A': 'foo bar foo bar foo bar foo foo'.split(),
                   'B': 'one one two three two two one three'.split(),
                   'C': np.arange(8), 'D': np.arange(8) * 2})
s
# Out:
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo    one  6  12
# 7  foo  three  7  14

# %%
s.loc[0]
# Out:
# A    foo
# B    one
# C      0
# D      0
# Name: 0, dtype: object

# %%
s.loc[0:3, 'B']
# Out:
# 0      one
# 1      one
# 2      two
# 3    three
# Name: B, dtype: object

# %%
s.loc[lambda s: s['C'] > 5]
# Out:
#      A      B  C   D
# 6  foo    one  6  12
# 7  foo  three  7  14

# %%
df
# Out:
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo    one  6  12
# 7  foo  three  7  14

# %%
df.loc[df.isin(['three']).any(axis=1)]#.index.tolist()
# Out:
#      A      B  C   D
# 3  bar  three  3   6
# 7  foo  three  7  14

# %%
s.loc[lambda s: s['C'] == 5]
# Out:
#      A    B  C   D
# 5  bar  two  5  10
